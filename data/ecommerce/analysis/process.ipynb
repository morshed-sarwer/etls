# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3032\3477112522.py:1: DtypeWarning: Columns (6,16,23,48,49,50,51,52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data.csv")

# %%
columns = df.columns
columns
selected_columns_df = df[["OrderId","OrderCode","OrderDate","CustomerID","TotalPrice","AfterPromoPrice","PromoPrice","GrandTotalPrice"]]
selected_columns_df
# Out:
#        OrderId                             OrderCode  \
# 0           79  3f1ca311-28dd-42ae-be4f-b01173119087
# 1           80  8c9fb2f1-7339-4ca1-89f8-767b989d7c55
# 2           81  d8591ac9-be1d-4200-bfee-71cd1a4451a2
# 3           82  1ce4c26a-e72e-46c1-b362-0977a0b69996
# 4           83  05bca283-83fd-4921-923a-69541b9e62ad
# ...        ...                                   ...
# 16385    16523  8577f9e1-2c54-40ae-ab46-d566c8887c55
# 16386    16524  1cf36c20-5cdc-466a-9ec7-561986e063bd
# 16387    16525  fa1b75a3-6623-4e38-9ee8-42eb8072ae20
# 16388    16526  a21fa0d8-eba3-4d7c-85f2-f95c287d63cf
# 16389    16527  73d06d5f-9efd-4e49-aa06-f0b5120c85a8
#
#                         OrderDate                            CustomerID  \
# 0      2022-09-15 04:39:23.800880  6e4fb72e-2cdc-47ad-a4db-0b04e0f83d59
# 1      2022-09-15 08:07:53.338027  91a9b569-2342-45dc-8c52-2d2a41176552
# 2      2022-09-15 10:48:29.721237  6e21e444-d5bf-4b3a-ac5b-4599bc2f9b9c
# ...

# %%
duplicate_df = selected_columns_df.duplicated(keep=False)
print(duplicate_df)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16385    False
# 16386    False
# 16387    False
# 16388    False
# 16389    False
# Length: 16390, dtype: bool
